# %%
from visual_dialog import dialog_utils
from fromage import models

# %%
# Load model used in the paper.
model_dir = './fromage_model/'
model = models.load_fromage(model_dir)

# %%
dialogs_csv_path = 'visual_dialog/dialogs.csv'
# images_path = 'visual_dialog/VisualDialog_val2018/'

# %%
dialogs_df = dialog_utils.load_dialogs(dialogs_csv_path)
dialogs_df.head()
# Out:
#   id round image_id question_id                               question  \
# 0  0     1   185565        9367                  is the photo in color
# 1  0     2   185565       16865             is it a professional photo
# 2  0     3   185565       43028                         is it well lit
# 3  0     4   185565       12354                          is it daytime
# 4  0     5   185565       41873  does this look like an adults bedroom
#
#   answer_id               answer
# 0      4754                  yes
# 1     15736                   no
# 2     15736                   no
# 3      9119  i don't see windows
# 4     13691                maybe

# %%
prompt_list = dialog_utils.get_prompt_list(dialogs_df)

# %%
print(prompt_list[25])
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x1535EABF6350>, 'is it light outside', 'yes', 'are there other people around', 'no', 'what color is the persons skies', 'white', 'can you tell which brand', "no i can't", 'what color is the persons trousers', 'red', 'what about their jacket', 'black', 'what color is their glasses', 'red and white', 'do they look happy', "i can't tell", 'does it look like that they have speed', 'not really']

# %%
prompt = []
for i in range(len(prompt_list)):
    if i < 10:
        if i % 3 == 2:
            prompt += [prompt_list[i][0]]

            # Use model to obtain output
            model_outputs = model.generate_for_images_and_texts(story_prompt, max_img_per_ret=3)

            print(prompt)
            prompt = []
        else:
            prompt += prompt_list[i]
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x1536CC6D7CA0>, 'is the photo in color', 'yes', 'is it a professional photo', 'no', 'is it well lit', 'no', 'is it daytime', "i don't see windows", 'does this look like an adults bedroom', 'maybe', 'is the room clean', 'no', 'can you tell what kind of computer it is', 'no not really', 'is it a flat screen', 'yes', "what's the desk made out of", 'cheap plastic or wood', <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x446 at 0x1535EABF5720>, 'is this in a park', 'yes, i believe it is', 'are there others around', 'no, she is alone', 'does she have a collection bucket', 'no', 'is her hair long', 'yes, pretty long', 'is she wearing a dress', "i don't think so, hard to tell", 'does she have shoes on', 'yes, flip flops', 'is there grass nearby', 'yes, everywhere', 'is it a sunny day', 'yes', 'are there trees', 'in the background there are trees', <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x640 at 0x1535EABF5750>]
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x1535EABF57E0>, 'is the picture in color', 'yes', 'how old does the woman look', "maybe late 20's to early 30's", 'are there any other people', 'no, just her and the bird', 'are there any animals', 'just the bird', 'what is she feeding the bird', "i can't tell, but it looks like a small rodent", 'is she wearing a hat', 'yes', 'what color is her shirt', 'mauve', 'what color is her hat', 'blonde', 'what kind of bird is it', 'a very large black bird with a white ring around his neck', <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x414 at 0x1535EABF5870>, 'is the picture in color', 'yes', 'is this a wedding picture', 'maybe', 'is the couple male and female', 'yes', 'is the cake 1 or more tiers', 'no', 'can you see other people', 'no', 'is this inside', 'yes', 'what color is the cake', 'white with blue lettering, but hard to see it', 'anything written on the cake', 'you cannot see it', 'any other decorations on the cake', 'not that i can see', <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=381x640 at 0x1535EABF58D0>]
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x640 at 0x1535EABF5BA0>, 'what color is the jet', 'white and blue', 'is it a commercial plane', 'yes', 'can the sky be seen', 'yes', 'are there any clouds', 'no', 'do you see any other planes in the picture', 'no', 'can you see anything else other than the plane', 'no', 'is the plane crashing', 'no', 'is the plane above any bodies of water', 'yes', 'are those bodies of water lakes', 'possibly', <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x419 at 0x1535EABF5C00>, 'do you see a lot of people', 'just 3', 'what is the tennis player wearing', 'white tennis dress', 'what color is her tennis racket', 'black', 'is she wearing a hat', 'a visor', 'is she close to the net', 'no', 'do you see another player', 'no', 'do you see a tennis bag', 'no', 'do you see trees', 'no', 'do you see anything next to her', 'nothing', <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x612 at 0x1535EABF5C60>]

# %%
from visual_dialog import dialog_utils
from fromage import models
import numpy as np
import matplotlib.pyplot as plt

# import argparse

# parser = argparse.ArgumentParser()
# parser.add_argument("--num_tests", type=int, required=True)
# parser.add_argument("--num_prompts_per_test", type=int, required=True)

# args = parser.parse_args()

# num_tests = args.num_tests
# num_pt = args.num_prompts_per_test

num_tests = 3
num_pt = 3

# Load model used in the paper.
# model_dir = './fromage_model/'
# model = models.load_fromage(model_dir)

# Load dialog csv
dialogs_csv_path = 'visual_dialog/dialogs.csv'
dialogs_df = dialog_utils.load_dialogs(dialogs_csv_path)

num_qa_per_dialog = 10

# Obtain all the dialogs
num_rows = num_tests * num_pt * num_qa_per_dialog
dialog_list = dialog_utils.get_prompt_list(dialogs_df, num_rows)
print('test')

prompt = []
model_outputs = []
for i in range(len(dialog_list)):
    if i < num_pt * num_tests:
        if i % num_pt == num_pt-1:
            prompt += [dialog_list[i][0]]

            # Obtain output of fromage model
            # output = model.generate_for_images_and_texts(prompt, num_words=200, ret_scale_factor=1, max_num_rets=3, temperature=0.5)
            # model_outputs.append(output)

            # print(prompt)

            dialog_utils.display_dialog(prompt)
            # print()
            # print("MODEL OUTPUT")
            # # dialog_utils.display_dialog(output)

            # # print(prompt)
            # # print()
            # # print(output)
            # print()
            # print()
            prompt = []
        else:
            prompt += dialog_list[i]
            # print(prompt)

# print("@@@@@@@@@@@@")
# for output in model_outputs:
#     print(output)
# print("@@@@@@@@@@@@")

with open('visual_dialog/model_output5.txt', 'w') as f:
    for item in model_outputs:
        f.write(f"{item}\n")

for output in model_outputs:
    if type(output) == list:
        fig, ax = plt.subplots(1, len(output), figsize=(3 * len(output), 3))
        for i, image in enumerate(output):
            image = np.array(image)
            ax[i].imshow(image)
            ax[i].set_title(f'Retrieval #{i+1}')
# Out:
# test2
# 0
# 185565
# 10
# 284024
# 20
# 574189
# 30
# 148816
# 40
# 88394
# 50
# 255061
# 60
# 36690
# 70
# 76113
# 80
# 112857
# test
# Q: is the photo in color, A: yes, Q: is it a professional photo, A: no, Q: is it well lit, A: no, Q: is it daytime, A: i don't see windows, Q: does this look like an adults bedroom, A: maybe, Q: is the room clean, A: no, Q: can you tell what kind of computer it is, A: no not really, Q: is it a flat screen, A: yes, Q: what's the desk made out of, A: cheap plastic or wood, Q: is there a computer chair, A: yes
# Q: is this in a park, A: yes, i believe it is, Q: are there others around, A: no, she is alone, Q: does she have a collection bucket, A: no, Q: is her hair long, A: yes, pretty long, Q: is she wearing a dress, A: i don't think so, hard to tell, Q: does she have shoes on, A: yes, flip flops, Q: is there grass nearby, A: yes, everywhere, Q: is it a sunny day, A: yes, Q: are there trees, A: in the background there are trees, Q: is the guitar new, A: i don't think so
# Q: is this in the bathroom, A: yes, Q: does he look sad, A: he looks puzzled, Q: how old is he, A: my best guess would be between 18 and 25, Q: puzzled like he drank to much last night and isn’t sure where he is, A: he is facing a mirror and looking down at something i cannot see, Q: does the bathroom appear to be nice, A: i can only see the mirror and a part of the sink, Q: does he have a beard, A: no, Q: is he wearing a shirt, A: no, Q: is he wearing glasses, A: yes, Q: is he wearing a watch, A: no, Q: any tattoos, A: no
# Q: is the picture in color, A: yes, Q: how old does the woman look, A: maybe late 20's to early 30's, Q: are there any other people, A: no, just her and the bird, Q: are there any animals, A: just the bird, Q: what is she feeding the bird, A: i can't tell, but it looks like a small rodent, Q: is she wearing a hat, A: yes, Q: what color is her shirt, A: mauve, Q: what color is her hat, A: blonde, Q: what kind of bird is it, A: a very large black bird with a white ring around his neck, Q: what else do you see, A: it appears to be at a zoo there are trees behind her
# Q: is the picture in color, A: yes, Q: is this a wedding picture, A: maybe, Q: is the couple male and female, A: yes, Q: is the cake 1 or more tiers, A: no, Q: can you see other people, A: no, Q: is this inside, A: yes, Q: what color is the cake, A: white with blue lettering, but hard to see it, Q: anything written on the cake, A: you cannot see it, Q: any other decorations on the cake, A: not that i can see, Q: can you see any plates, A: no
# Q: is she alone, A: yes, Q: is she wearing a skirt, A: yes, Q: what color is the skirt, A: black, Q: what color are her shoes, A: can't see her feet, Q: is her hair pulled back, A: yes, Q: is she on the left or right, A: left, Q: is her hair in a ponytail, A: yes, Q: is she walking, A: no, standing still, Q: is she bent down, A: a little, Q: is it sunny, A: yes
# Q: what color is the jet, A: white and blue, Q: is it a commercial plane, A: yes, Q: can the sky be seen, A: yes, Q: are there any clouds, A: no, Q: do you see any other planes in the picture, A: no, Q: can you see anything else other than the plane, A: no, Q: is the plane crashing, A: no, Q: is the plane above any bodies of water, A: yes, Q: are those bodies of water lakes, A: possibly, Q: is there any text on the plane, A: not that i can see
# Q: do you see a lot of people, A: just 3, Q: what is the tennis player wearing, A: white tennis dress, Q: what color is her tennis racket, A: black, Q: is she wearing a hat, A: a visor, Q: is she close to the net, A: no, Q: do you see another player, A: no, Q: do you see a tennis bag, A: no, Q: do you see trees, A: no, Q: do you see anything next to her, A: nothing, Q: does she look mad, A: no
# Q: what kind of food, A: looks like fried chicken and some rice and sauce, Q: what color are the plates, A: they are orange, Q: what color are the bowls, A: also orange, Q: are there any drinks, A: no drinks are visible, Q: are there any people, A: no people are visible, Q: what color is the table, A: the table is white, Q: is this in a kitchen, A: it looks like a domestic kitchen, Q: is there a tablecloth on the table, A: i can't tell for sure, Q: is there any silverware, A: yes all around, Q: can you see the tub, A: no
