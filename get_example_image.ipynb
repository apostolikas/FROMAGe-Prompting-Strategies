# %%
import json
from visual_dialog import dialog_utils

gpt_path = "./visual_dialog/1_examples_5_qa_inc_QA_GPT.json" # 20
caption_QA_path = "visual_dialog/1_examples_5_qa_inc_QA.json" # 19
caption_path = "visual_dialog/1_examples_5_qa_only_caption.json" # 20

with open(gpt_path, 'r') as file:
    data = json.load(file)

# Retrieve the lists
prompts = data['prompts']
outputs = data['outputs']

for i, prompt in enumerate(prompts):
    if i == 20:
        print(prompts[i])


dialog_utils.display_output(outputs[20])
# Out:
# ['A chair on the beach with boats in view offshore, people sitting on the boats.']
